# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Country 1

# %%
data = pd.read_excel("Country1.xlsx")

# %%
data
# Out:
#           date       region_1      region_2     region_3       national
# 0   2021-05-03    9001.440000   1619.940000   273.980000   10895.360000
# 1   2021-05-10   56345.450000   9939.090000  1584.030000   67868.570000
# 2   2021-05-17   61777.170000  10835.510000  1643.880000   74256.560000
# 3   2021-05-24   57489.250000   9888.550000  1598.660000   68976.460000
# 4   2021-05-31   58345.770000  10048.150000  1512.210000   69906.130000
# ..         ...            ...           ...          ...            ...
# 159 2024-05-20  188709.531250  19842.839844  2526.968506  160995.206841
# 160 2024-05-27  197548.640625  21274.343750  2653.004395  160851.703560
# 161 2024-06-03  196358.015625  20519.367188  2696.856934  148069.617353
# 162 2024-06-10  179878.281250  18965.017578  2497.269531  132974.770526
# 163 2024-06-17  175681.453125  19437.660156  2386.359619  125136.221637
#
# [164 rows x 5 columns]

# %%
forecast_start = 154  # The index where forecast starts

# Plot historical and future data separately for each column
columns = ['region_1', 'region_2', 'region_3', 'national']

# Set up the figure and axes
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10, 15))
axes = axes.flatten()

# Loop over each column (region_1, region_2, region_3, national)
for i, col in enumerate(columns):
    # Plot historical data
    axes[i].plot(data['date'][:forecast_start], data[col][:forecast_start], label='Historical', color='blue')
    
    # Plot forecasted data
    axes[i].plot(data['date'][forecast_start:], data[col][forecast_start:], label='Forecast', color='red')
    
    # Add labels and title
    axes[i].set_title(f"{col.capitalize()} - Historical vs Forecasted")
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Sales')
    axes[i].legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Country 2

# %%
data = pd.read_excel("Country2.xlsx")

# %%
data
# Out:
#           date      region_1      region_2      region_3       national
# 0   2019-01-07  10827.200000  54055.750000  34619.625000   99502.575000
# 1   2019-01-14  10523.375000  51052.687500  30550.100000   92126.162500
# 2   2019-01-21  12860.512500  57290.200000  36072.287500  106223.000000
# 3   2019-01-28  14841.462500  62758.175000  41300.537500  118900.175000
# 4   2019-02-04  15490.062500  71519.662500  45111.787500  132121.512500
# ..         ...           ...           ...           ...            ...
# 245 2023-09-18   4325.507324  15059.749023  12182.586914   99155.976619
# 246 2023-09-25   4857.002441  17615.482422  13643.638672  109590.041434
# 247 2023-10-02   4354.421875  16184.755859  12569.324219  115582.667864
# 248 2023-10-09   3764.092529  14768.507812  11455.876953  118627.337257
# 249 2023-10-16   4055.696289  15255.224609  12458.901367  119232.839252
#
# [250 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the dataset is already loaded in the variable `data`
# Mark the forecasted data by using the last 2 rows
forecast_start = 240  # The index where forecast starts

# Plot historical and future data separately for each column
columns = ['region_1', 'region_2', 'region_3', 'national']

# Set up the figure and axes
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10, 15))
axes = axes.flatten()

# Loop over each column (region_1, region_2, region_3, national)
for i, col in enumerate(columns):
    # Plot historical data
    axes[i].plot(data['date'][:forecast_start], data[col][:forecast_start], label='Historical', color='blue')
    
    # Plot forecasted data
    axes[i].plot(data['date'][forecast_start:], data[col][forecast_start:], label='Forecast', color='red')
    
    # Add labels and title
    axes[i].set_title(f"{col.capitalize()} - Historical vs Forecasted")
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Sales')
    axes[i].legend()

# Adjust layout
plt.tight_layout()
plt.show()
